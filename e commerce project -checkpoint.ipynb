# %%
import numpy as np

# %%
import pandas as pd

# %%
order=pd.read_excel("Company X - Order Report.xlsx")
pincode=pd.read_excel("Company X - Pincode Zones.xlsx")
product=pd.read_excel("Company X - SKU Master.xlsx")
invoice=pd.read_excel("Courier Company - Invoice.xlsx")
rates=pd.read_excel("Courier Company - Rates.xlsx")

# %%
order.head(1)
# Out:
#    ExternOrderNo            SKU  Order Qty
# 0     2001827036  8904223818706        1.0

# %%
pincode.head(1)
# Out:
#    Warehouse Pincode  Customer Pincode Zone
# 0             121003            507101    d

# %%
product.head(1)
# Out:
#              SKU  Weight (g)
# 0  8904223815682         210

# %%
rates.head(1)
# Out:
#   Zone  Weight Slabs  Forward Fixed Charge  \
# 0    A           0.5                  29.5
#
#    Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                   23.6              13.6
#
#    RTO Additional Weight Slab Charge
# 0                               23.6

# %%
invoice.head(1)
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232             1.3             121003
#
#    Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)
# 0            507101    d  Forward charges                 135.0

# %%
order.drop_duplicates(inplace=True)
product.drop_duplicates(inplace=True)
pincode.drop_duplicates(inplace=True)
invoice.drop_duplicates(inplace=True)
rates.drop_duplicates(inplace=True)

# %%
pd.merge(product,order,on="SKU",how = "inner")
# Out:
#                SKU  Weight (g)  ExternOrderNo  Order Qty
# 0    8904223815682         210     2001808801        1.0
# 1    8904223815859         165     2001820978        1.0
# 2    8904223815859         165     2001811363        1.0
# 3    8904223815859         165     2001808801        1.0
# 4    8904223815859         165     2001808675        1.0
# ..             ...         ...            ...        ...
# 393  8904223819512         210     2001806733        1.0
# 394  8904223819543         300     2001811306        1.0
# 395     SACHETS001          10     2001827036        1.0
# 396     SACHETS001          10     2001825261        1.0
# 397     SACHETS001          10     2001819252        1.0
#
# [398 rows x 4 columns]

# %%
rates["Zone"]= rates["Zone"].str.lower()

# %%
comp=pd.merge(
    pd.merge(
        invoice,pd.merge(
            pincode,rates,on="Zone",how="inner"),
        on="Customer Pincode",how="inner"),
    pd.merge(
        product,order,on="SKU",how = "inner"),
    left_on="Order ID",right_on="ExternOrderNo",how="inner")

# %%
comp
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode_x  \
# 0    1091117222124  2001806232             1.3               121003
# 1    1091117222124  2001806232             1.3               121003
# 2    1091117222194  2001806273             1.0               121003
# 3    1091117222194  2001806273             1.0               121003
# 4    1091117222194  2001806273             1.0               121003
# ..             ...         ...             ...                  ...
# 393  1091117614452  2001809383             0.5               121003
# 394  1091117614452  2001809383             0.5               121003
# 395  1091117614452  2001809383             0.5               121003
# 396  1091120922803  2001820978             0.5               121003
# 397  1091120922803  2001820978             0.5               121003
#
#      Customer Pincode Zone_x         Type of Shipment  Billing Amount (Rs.)  \
# 0              507101      d          Forward charges                 135.0
# 1              507101      d          Forward charges                 135.0
# 2              486886      d          Forward charges                  90.2
# 3              486886      d          Forward charges                  90.2
# 4              486886      d          Forward charges                  90.2
# ..                ...    ...                      ...                   ...
# 393            303702      d  Forward and RTO charges                  86.7
# 394            303702      d  Forward and RTO charges                  86.7
# 395            303702      d  Forward and RTO charges                  86.7
# 396            313301      d          Forward charges                  45.4
# 397            313301      d          Forward charges                  45.4
#
#      Warehouse Pincode_y Zone_y  Weight Slabs  Forward Fixed Charge  \
# 0                 121003      d           1.5                  45.4
# 1                 121003      d           1.5                  45.4
# 2                 121003      d           1.5                  45.4
# 3                 121003      d           1.5                  45.4
# 4                 121003      d           1.5                  45.4
# ..                   ...    ...           ...                   ...
# 393               121003      b           1.0                  33.0
# 394               121003      b           1.0                  33.0
# 395               121003      b           1.0                  33.0
# 396               121003      b           1.0                  33.0
# 397               121003      b           1.0                  33.0
#
#      Forward Additional Weight Slab Charge  RTO Fixed Charge  \
# 0                                     44.8              41.3
# 1                                     44.8              41.3
# 2                                     44.8              41.3
# 3                                     44.8              41.3
# 4                                     44.8              41.3
# ..                                     ...               ...
# 393                                   28.3              20.5
# 394                                   28.3              20.5
# 395                                   28.3              20.5
# 396                                   28.3              20.5
# 397                                   28.3              20.5
#
#      RTO Additional Weight Slab Charge            SKU  Weight (g)  \
# 0                                 44.8  8904223818645         137
# 1                                 44.8  8904223819147         240
# 2                                 44.8  8904223818706         127
# 3                                 44.8  8904223818850         240
# 4                                 44.8  8904223818942         133
# ..                                 ...            ...         ...
# 393                               28.3  8904223818706         127
# 394                               28.3  8904223818850         240
# 395                               28.3  8904223819468         240
# 396                               28.3  8904223815859         165
# 397                               28.3  8904223817501         350
#
#      ExternOrderNo  Order Qty
# 0       2001806232        6.0
# 1       2001806232        2.0
# 2       2001806273        1.0
# 3       2001806273        1.0
# 4       2001806273        1.0
# ..             ...        ...
# 393     2001809383        1.0
# 394     2001809383        1.0
# 395     2001809383        1.0
# 396     2001820978        1.0
# 397     2001820978        1.0
#
# [398 rows x 19 columns]

# %%
comp["Actual Weight(KG)"]= (comp["Weight (g)"]*comp["Order Qty"])/1000

# %%
awb_data=comp.groupby("AWB Code").agg({"Order ID":"first","Charged Weight":"first","Warehouse Pincode_x":"first",
                             "Customer Pincode":"first","Type of Shipment":"first",
                              "Billing Amount (Rs.)":"first","Zone_y":"first","Weight Slabs":"first",
                              "Forward Fixed Charge":"first","Forward Additional Weight Slab Charge":"first",
                              "RTO Fixed Charge":"first","RTO Additional Weight Slab Charge":"first",
                              "SKU":"count","Order Qty":"sum","Actual Weight(KG)":"sum" })

# %%
awb_data["Slab_count"]= np.ceil(awb_data["Actual Weight(KG)"]/awb_data["Weight Slabs"])

# %%
def actual_price(x):
    if x["Type of Shipment"]=="Forward charges":
        return x["Slab_count"]*x["Forward Additional Weight Slab Charge"]+x["Forward Fixed Charge"]
    elif x["Type of Shipment"]=="Forward and RTO charges" :
        return (x["Slab_count"]*x["Forward Additional Weight Slab Charge"]+x["Forward Fixed Charge"]
               )+(x["Slab_count"]*x["RTO Additional Weight Slab Charge"]+x["RTO Fixed Charge"])
    else:
        return "Error"

# %%
awb_data["Actual_Price"]=awb_data.apply(lambda x: actual_price(x),axis=1)

# %%
awb_data["Acutal vs invoice"]= awb_data["Actual_Price"]-awb_data["Billing Amount (Rs.)"]

# %%
awb_data["Actual vs invoice"]=awb_data["Acutal vs invoice"].astype(int)

# %%
def finds(x):
    if x["Actual vs invoice"]<0:
        return "Total Orders where X has been undercharged	"
    elif x["Actual vs invoice"]==0:
        return "Total orders where X has been correctly charged"
    else:
        return "Total Orders where X has been overcharged"

# %%
awb_data["Status"] = awb_data.apply(lambda x: finds(x),axis=1)

# %%
awb=awb_data.groupby("Status").agg({"Order ID":"count","Actual vs invoice":"sum"})

# %%
awb
# Out:
#                                                  Order ID  Actual vs invoice
# Status
# Total Orders where X has been overcharged              34                920
# Total Orders where X has been undercharged\t           63              -3663
# Total orders where X has been correctly charged        27                  0

# %%
920-3663
# Out:
# -2743

# %%
2743/124
# Out:
# 22.120967741935484

# %%
int(list(awb_data.groupby("Status").agg({"Order ID":"count","Actual vs invoice":"sum"}).values[1:2,1:2])[0])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_16780\3683019163.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   int(list(awb_data.groupby("Status").agg({"Order ID":"count","Actual vs invoice":"sum"}).values[1:2,1:2])[0])
# -3663

# %%
awb.to_excel('Summary.xlsx')
